# %% [markdown]
# ## Bloco 1 — Introdução e subida de arquivos

# %% [markdown]
# **Conteúdo:**
#
# * O que é um arquivo CSV
#
# * O que é um arquivo Excel
#
# * Diferença entre dado estruturado e não estruturado
#
# * Como subir arquivo no Google Colab
#
# * Como ler arquivo com pandas

# %% [markdown]
# **Comandos principais para entender os dados:**
#
# * df.head()
# * df.tail()
# * df.shape
# * df.columns
# * df.info()
# * df.describe()

# %% [markdown]
# ### Selecionar colunas

# %% [markdown]
# ### Filtragem

# %% [markdown]
# ### Criando nova coluna

# %% [markdown]
# ### ordenando

# %% [markdown]
# ## Tratamento simples e análise rápida

# %% [markdown]
# **Conteúdo:**
#
# * valores ausentes
#
# * renomear colunas
#
# * média, soma, máximo, mínimo
#
# * agrupamento simples

# %% [markdown]
# Rename

# %% [markdown]
# Valores bases
